# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create set of random longitudes and latitudes
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add longs and lats to list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
requests.get(city_url).json()
# Out:
# {'coord': {'lon': 102.35, 'lat': -0.3167},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 73.42,
#   'feels_like': 75.02,
#   'temp_min': 73.42,
#   'temp_max': 73.42,
#   'pressure': 1010,
#   'humidity': 97,
#   'sea_level': 1010,
#   'grnd_level': 1008},
#  'visibility': 10000,
#  'wind': {'speed': 0.78, 'deg': 140, 'gust': 1.05},
#  'clouds': {'all': 98},
#  'dt': 1618427264,
#  'sys': {'country': 'ID', 'sunrise': 1618441638, 'sunset': 1618485216},
#  'timezone': 25200,
#  'id': 1642773,
#  'name': 'Japura',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#Loop through all cities in list
for i, city in enumerate(cities):
    
    #Group cities in blocks of 50
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create endpoint URLwith each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log URL, record, and set numbers and city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to record_count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | morondava
# Processing Record 3 of Set 1 | vao
# Processing Record 4 of Set 1 | padina
# Processing Record 5 of Set 1 | araouane
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | doctor juan manuel frutos
# Processing Record 10 of Set 1 | dyersburg
# Processing Record 11 of Set 1 | saint-francois
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | nouadhibou
# Processing Record 14 of Set 1 | kaga
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | hofn
# Processing Record 18 of Set 1 | gat
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | salalah
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | artsvaberd
# Processing Record 27 of Set 1 | saint-augustin
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | beisfjord
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | alofi
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | ous
# Processing Record 36 of Set 1 | naze
# Processing Record 37 of Set 1 | road town
# Processing Record 38 of Set 1 | gorgan
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | wladyslawowo
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | nelson bay
# Processing Record 45 of Set 1 | binche
# Processing Record 46 of Set 1 | evensk
# Processing Record 47 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | shimoda
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | waipawa
# Processing Record 7 of Set 2 | omboue
# Processing Record 8 of Set 2 | bambous virieux
# Processing Record 9 of Set 2 | padang
# Processing Record 10 of Set 2 | rosarito
# Processing Record 11 of Set 2 | severo-kurilsk
# Processing Record 12 of Set 2 | nizhniy kuranakh
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | san quintin
# Processing Record 17 of Set 2 | namatanai
# Processing Record 18 of Set 2 | markala
# Processing Record 19 of Set 2 | aasiaat
# Processing Record 20 of Set 2 | portland
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | aksu
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | kahului
# Processing Record 25 of Set 2 | souillac
# Processing Record 26 of Set 2 | pangnirtung
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | prince rupert
# Processing Record 29 of Set 2 | dukat
# Processing Record 30 of Set 2 | shetpe
# Processing Record 31 of Set 2 | leninsk
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | ossora
# Processing Record 34 of Set 2 | daniel flores
# Processing Record 35 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 2 | hamilton
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | rodionovo-nesvetayskaya
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | ponta do sol
# Processing Record 41 of Set 2 | lompoc
# Processing Record 42 of Set 2 | belaya gora
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | sandnessjoen
# Processing Record 46 of Set 2 | svetlaya
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | katsuura
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | floro
# Processing Record 1 of Set 3 | bundaberg
# Processing Record 2 of Set 3 | gilgit
# Processing Record 3 of Set 3 | beringovskiy
# Processing Record 4 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 3 | camacari
# Processing Record 6 of Set 3 | cherskiy
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | meadow lake
# Processing Record 10 of Set 3 | bontang
# Processing Record 11 of Set 3 | kodinsk
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | tarakan
# Processing Record 14 of Set 3 | kieta
# Processing Record 15 of Set 3 | esperance
# Processing Record 16 of Set 3 | neiafu
# Processing Record 17 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | viedma
# Processing Record 21 of Set 3 | bilkha
# Processing Record 22 of Set 3 | luanda
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | atuona
# Processing Record 25 of Set 3 | pisco
# Processing Record 26 of Set 3 | los llanos de aridane
# Processing Record 27 of Set 3 | kendari
# Processing Record 28 of Set 3 | guerrero negro
# Processing Record 29 of Set 3 | soyo
# Processing Record 30 of Set 3 | virginia beach
# Processing Record 31 of Set 3 | sabha
# Processing Record 32 of Set 3 | hutchinson
# Processing Record 33 of Set 3 | dunedin
# Processing Record 34 of Set 3 | agirish
# Processing Record 35 of Set 3 | thomaston
# Processing Record 36 of Set 3 | thinadhoo
# Processing Record 37 of Set 3 | arlit
# Processing Record 38 of Set 3 | dikson
# Processing Record 39 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 3 | kant
# Processing Record 41 of Set 3 | okha
# Processing Record 42 of Set 3 | sobolevo
# Processing Record 43 of Set 3 | praia da vitoria
# Processing Record 44 of Set 3 | bobingen
# Processing Record 45 of Set 3 | acapulco
# Processing Record 46 of Set 3 | longyearbyen
# Processing Record 47 of Set 3 | asau
# Processing Record 48 of Set 3 | puerto ayora
# Processing Record 49 of Set 3 | tura
# Processing Record 50 of Set 3 | whitley bay
# Processing Record 1 of Set 4 | livaderon
# City not found. Skipping...
# Processing Record 2 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 4 | yatou
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | pinega
# Processing Record 6 of Set 4 | yulara
# Processing Record 7 of Set 4 | muisne
# Processing Record 8 of Set 4 | amapa
# Processing Record 9 of Set 4 | lebu
# Processing Record 10 of Set 4 | coihaique
# Processing Record 11 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 4 | homer
# Processing Record 13 of Set 4 | broome
# Processing Record 14 of Set 4 | nuevo progreso
# Processing Record 15 of Set 4 | avarua
# Processing Record 16 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 4 | chuy
# Processing Record 18 of Set 4 | naro moru
# Processing Record 19 of Set 4 | tigil
# Processing Record 20 of Set 4 | kudahuvadhoo
# Processing Record 21 of Set 4 | manacapuru
# Processing Record 22 of Set 4 | hambantota
# Processing Record 23 of Set 4 | mnogovershinnyy
# Processing Record 24 of Set 4 | ixtapa
# Processing Record 25 of Set 4 | iqaluit
# Processing Record 26 of Set 4 | weligama
# Processing Record 27 of Set 4 | jiazi
# Processing Record 28 of Set 4 | ternate
# Processing Record 29 of Set 4 | ostersund
# Processing Record 30 of Set 4 | muncar
# Processing Record 31 of Set 4 | kokopo
# Processing Record 32 of Set 4 | port lincoln
# Processing Record 33 of Set 4 | san patricio
# Processing Record 34 of Set 4 | goba
# Processing Record 35 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 4 | codrington
# Processing Record 37 of Set 4 | provideniya
# Processing Record 38 of Set 4 | sur
# Processing Record 39 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 40 of Set 4 | tiksi
# Processing Record 41 of Set 4 | sola
# Processing Record 42 of Set 4 | hobart
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | ilhabela
# Processing Record 45 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 46 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 4 | san cristobal
# Processing Record 48 of Set 4 | erenhot
# Processing Record 49 of Set 4 | la peca
# Processing Record 50 of Set 4 | thompson
# Processing Record 1 of Set 5 | harer
# Processing Record 2 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 3 of Set 5 | champerico
# Processing Record 4 of Set 5 | ames
# Processing Record 5 of Set 5 | diffa
# Processing Record 6 of Set 5 | mokhsogollokh
# Processing Record 7 of Set 5 | surt
# Processing Record 8 of Set 5 | daru
# Processing Record 9 of Set 5 | kirakira
# Processing Record 10 of Set 5 | grand gaube
# Processing Record 11 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 5 | kaili
# Processing Record 13 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 5 | laguna
# Processing Record 15 of Set 5 | tessalit
# Processing Record 16 of Set 5 | chokurdakh
# Processing Record 17 of Set 5 | opole lubelskie
# Processing Record 18 of Set 5 | farafangana
# Processing Record 19 of Set 5 | namibe
# Processing Record 20 of Set 5 | do gonbadan
# Processing Record 21 of Set 5 | klaksvik
# Processing Record 22 of Set 5 | makakilo city
# Processing Record 23 of Set 5 | manoel urbano
# Processing Record 24 of Set 5 | kulhudhuffushi
# Processing Record 25 of Set 5 | tahe
# Processing Record 26 of Set 5 | port blair
# Processing Record 27 of Set 5 | rawson
# Processing Record 28 of Set 5 | gbarnga
# Processing Record 29 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 5 | ndele
# Processing Record 31 of Set 5 | veraval
# Processing Record 32 of Set 5 | nome
# Processing Record 33 of Set 5 | aneho
# Processing Record 34 of Set 5 | luderitz
# Processing Record 35 of Set 5 | caravelas
# Processing Record 36 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 5 | huazolotitlan
# City not found. Skipping...
# Processing Record 38 of Set 5 | lushunkou
# City not found. Skipping...
# Processing Record 39 of Set 5 | gotsu
# Processing Record 40 of Set 5 | necochea
# Processing Record 41 of Set 5 | pevek
# Processing Record 42 of Set 5 | kokkola
# Processing Record 43 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 5 | cabo san lucas
# Processing Record 45 of Set 5 | castro
# Processing Record 46 of Set 5 | kodiak
# Processing Record 47 of Set 5 | turinsk
# Processing Record 48 of Set 5 | cayenne
# Processing Record 49 of Set 5 | kloulklubed
# Processing Record 50 of Set 5 | san rafael del sur
# Processing Record 1 of Set 6 | inuvik
# Processing Record 2 of Set 6 | jishou
# Processing Record 3 of Set 6 | sitka
# Processing Record 4 of Set 6 | otaki
# Processing Record 5 of Set 6 | sao filipe
# Processing Record 6 of Set 6 | vila velha
# Processing Record 7 of Set 6 | yoichi
# Processing Record 8 of Set 6 | kalemie
# Processing Record 9 of Set 6 | tautira
# Processing Record 10 of Set 6 | amarpatan
# Processing Record 11 of Set 6 | camacha
# Processing Record 12 of Set 6 | shirokiy
# Processing Record 13 of Set 6 | berlevag
# Processing Record 14 of Set 6 | hasaki
# Processing Record 15 of Set 6 | petukhovo
# Processing Record 16 of Set 6 | tambopata
# Processing Record 17 of Set 6 | bathsheba
# Processing Record 18 of Set 6 | erzin
# Processing Record 19 of Set 6 | yining
# Processing Record 20 of Set 6 | nueve de julio
# Processing Record 21 of Set 6 | palmer
# Processing Record 22 of Set 6 | bowen
# Processing Record 23 of Set 6 | ostrovnoy
# Processing Record 24 of Set 6 | oistins
# Processing Record 25 of Set 6 | hobyo
# Processing Record 26 of Set 6 | bilibino
# Processing Record 27 of Set 6 | sungaipenuh
# Processing Record 28 of Set 6 | tabou
# Processing Record 29 of Set 6 | nanortalik
# Processing Record 30 of Set 6 | lewiston
# Processing Record 31 of Set 6 | uddevalla
# Processing Record 32 of Set 6 | half moon bay
# Processing Record 33 of Set 6 | abu dhabi
# Processing Record 34 of Set 6 | kostinbrod
# Processing Record 35 of Set 6 | menongue
# Processing Record 36 of Set 6 | kaitangata
# Processing Record 37 of Set 6 | aquiraz
# Processing Record 38 of Set 6 | constitucion
# Processing Record 39 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 6 | sibolga
# Processing Record 41 of Set 6 | hermiston
# Processing Record 42 of Set 6 | lagoa
# Processing Record 43 of Set 6 | nyrob
# Processing Record 44 of Set 6 | matay
# Processing Record 45 of Set 6 | talnakh
# Processing Record 46 of Set 6 | bayji
# Processing Record 47 of Set 6 | fortuna
# Processing Record 48 of Set 6 | bafra
# Processing Record 49 of Set 6 | socorro
# Processing Record 50 of Set 6 | moranbah
# Processing Record 1 of Set 7 | khashuri
# Processing Record 2 of Set 7 | isiro
# Processing Record 3 of Set 7 | yellowknife
# Processing Record 4 of Set 7 | palora
# Processing Record 5 of Set 7 | udachnyy
# Processing Record 6 of Set 7 | urucara
# Processing Record 7 of Set 7 | chunskiy
# Processing Record 8 of Set 7 | forrest city
# Processing Record 9 of Set 7 | khani
# Processing Record 10 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 7 | snasa
# Processing Record 12 of Set 7 | honningsvag
# Processing Record 13 of Set 7 | hendersonville
# Processing Record 14 of Set 7 | barcelos
# Processing Record 15 of Set 7 | baracoa
# Processing Record 16 of Set 7 | havelock
# Processing Record 17 of Set 7 | borogontsy
# Processing Record 18 of Set 7 | veletma
# City not found. Skipping...
# Processing Record 19 of Set 7 | taoudenni
# Processing Record 20 of Set 7 | husavik
# Processing Record 21 of Set 7 | shenkursk
# Processing Record 22 of Set 7 | banff
# Processing Record 23 of Set 7 | ishinomaki
# Processing Record 24 of Set 7 | arefu
# Processing Record 25 of Set 7 | ondjiva
# Processing Record 26 of Set 7 | mareeba
# Processing Record 27 of Set 7 | mansehra
# Processing Record 28 of Set 7 | mount gambier
# Processing Record 29 of Set 7 | praia
# Processing Record 30 of Set 7 | pitimbu
# Processing Record 31 of Set 7 | torbay
# Processing Record 32 of Set 7 | adrar
# Processing Record 33 of Set 7 | sinnai
# Processing Record 34 of Set 7 | tezpur
# Processing Record 35 of Set 7 | marmaris
# Processing Record 36 of Set 7 | teya
# Processing Record 37 of Set 7 | nam tha
# City not found. Skipping...
# Processing Record 38 of Set 7 | iskandar
# Processing Record 39 of Set 7 | deputatskiy
# Processing Record 40 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 41 of Set 7 | llangefni
# Processing Record 42 of Set 7 | luba
# Processing Record 43 of Set 7 | kiunga
# Processing Record 44 of Set 7 | benguela
# Processing Record 45 of Set 7 | treinta y tres
# Processing Record 46 of Set 7 | central point
# Processing Record 47 of Set 7 | keetmanshoop
# Processing Record 48 of Set 7 | berdigestyakh
# Processing Record 49 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 7 | elbistan
# Processing Record 1 of Set 8 | cap malheureux
# Processing Record 2 of Set 8 | bo
# City not found. Skipping...
# Processing Record 3 of Set 8 | puerto del rosario
# Processing Record 4 of Set 8 | boyolangu
# Processing Record 5 of Set 8 | kavaratti
# Processing Record 6 of Set 8 | eyl
# Processing Record 7 of Set 8 | primero de marzo
# Processing Record 8 of Set 8 | clyde river
# Processing Record 9 of Set 8 | semey
# Processing Record 10 of Set 8 | oranjemund
# Processing Record 11 of Set 8 | shingu
# Processing Record 12 of Set 8 | oriximina
# Processing Record 13 of Set 8 | arak
# Processing Record 14 of Set 8 | balabac
# Processing Record 15 of Set 8 | darnah
# Processing Record 16 of Set 8 | victor harbor
# Processing Record 17 of Set 8 | fukue
# Processing Record 18 of Set 8 | bowmore
# Processing Record 19 of Set 8 | dzaoudzi
# Processing Record 20 of Set 8 | peruibe
# Processing Record 21 of Set 8 | egvekinot
# Processing Record 22 of Set 8 | riaba
# City not found. Skipping...
# Processing Record 23 of Set 8 | crateus
# Processing Record 24 of Set 8 | sayyan
# Processing Record 25 of Set 8 | yuli
# Processing Record 26 of Set 8 | salinopolis
# Processing Record 27 of Set 8 | alice town
# Processing Record 28 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 8 | troitsko-pechorsk
# Processing Record 30 of Set 8 | eureka
# Processing Record 31 of Set 8 | zabol
# Processing Record 32 of Set 8 | olga
# Processing Record 33 of Set 8 | muhos
# Processing Record 34 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 35 of Set 8 | tuatapere
# Processing Record 36 of Set 8 | juneau
# Processing Record 37 of Set 8 | kyaikto
# Processing Record 38 of Set 8 | cape town
# Processing Record 39 of Set 8 | kalmar
# Processing Record 40 of Set 8 | iwanai
# Processing Record 41 of Set 8 | mayo
# Processing Record 42 of Set 8 | baruun-urt
# Processing Record 43 of Set 8 | mimongo
# Processing Record 44 of Set 8 | panguipulli
# Processing Record 45 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 8 | cururupu
# Processing Record 47 of Set 8 | miraflores
# Processing Record 48 of Set 8 | narsaq
# Processing Record 49 of Set 8 | alyangula
# Processing Record 50 of Set 8 | miri
# Processing Record 1 of Set 9 | ereymentau
# Processing Record 2 of Set 9 | lima
# Processing Record 3 of Set 9 | flinders
# Processing Record 4 of Set 9 | sedalia
# Processing Record 5 of Set 9 | callaway
# Processing Record 6 of Set 9 | baturaja
# Processing Record 7 of Set 9 | samarai
# Processing Record 8 of Set 9 | cockburn town
# Processing Record 9 of Set 9 | wenzhou
# Processing Record 10 of Set 9 | changping
# Processing Record 11 of Set 9 | florencia
# Processing Record 12 of Set 9 | bonavista
# Processing Record 13 of Set 9 | darhan
# Processing Record 14 of Set 9 | pozo colorado
# Processing Record 15 of Set 9 | denpasar
# Processing Record 16 of Set 9 | goulburn
# Processing Record 17 of Set 9 | christchurch
# Processing Record 18 of Set 9 | silay
# Processing Record 19 of Set 9 | muros
# Processing Record 20 of Set 9 | rosetta
# Processing Record 21 of Set 9 | qaqortoq
# Processing Record 22 of Set 9 | matagami
# Processing Record 23 of Set 9 | sinnamary
# Processing Record 24 of Set 9 | hailar
# Processing Record 25 of Set 9 | shache
# Processing Record 26 of Set 9 | bestobe
# Processing Record 27 of Set 9 | atar
# Processing Record 28 of Set 9 | fuyang
# Processing Record 29 of Set 9 | santa cruz
# Processing Record 30 of Set 9 | winnemucca
# Processing Record 31 of Set 9 | whitefish
# Processing Record 32 of Set 9 | chapada dos guimaraes
# Processing Record 33 of Set 9 | fairbanks
# Processing Record 34 of Set 9 | madimba
# Processing Record 35 of Set 9 | caruray
# Processing Record 36 of Set 9 | cocobeach
# Processing Record 37 of Set 9 | gamba
# Processing Record 38 of Set 9 | sorland
# Processing Record 39 of Set 9 | port hedland
# Processing Record 40 of Set 9 | buala
# Processing Record 41 of Set 9 | poum
# Processing Record 42 of Set 9 | lasa
# Processing Record 43 of Set 9 | bandarbeyla
# Processing Record 44 of Set 9 | tiznit
# Processing Record 45 of Set 9 | nioki
# Processing Record 46 of Set 9 | kisesa
# Processing Record 47 of Set 9 | boa vista
# Processing Record 48 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 9 | magadan
# Processing Record 50 of Set 9 | leduc
# Processing Record 1 of Set 10 | lenger
# Processing Record 2 of Set 10 | san joaquin
# Processing Record 3 of Set 10 | harrogate
# Processing Record 4 of Set 10 | bapatla
# Processing Record 5 of Set 10 | halifax
# Processing Record 6 of Set 10 | talara
# Processing Record 7 of Set 10 | sillamae
# Processing Record 8 of Set 10 | woodway
# Processing Record 9 of Set 10 | jiaxing
# Processing Record 10 of Set 10 | ponta delgada
# Processing Record 11 of Set 10 | teguldet
# Processing Record 12 of Set 10 | bayeux
# Processing Record 13 of Set 10 | sumbe
# Processing Record 14 of Set 10 | zhigansk
# Processing Record 15 of Set 10 | albury
# Processing Record 16 of Set 10 | college
# Processing Record 17 of Set 10 | wenatchee
# Processing Record 18 of Set 10 | lata
# Processing Record 19 of Set 10 | khorramshahr
# Processing Record 20 of Set 10 | tabuk
# Processing Record 21 of Set 10 | zyryanka
# Processing Record 22 of Set 10 | ancud
# Processing Record 23 of Set 10 | tingo maria
# Processing Record 24 of Set 10 | banda
# Processing Record 25 of Set 10 | cidreira
# Processing Record 26 of Set 10 | yaan
# Processing Record 27 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 28 of Set 10 | aykhal
# Processing Record 29 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 30 of Set 10 | trinidad
# Processing Record 31 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 32 of Set 10 | biltine
# Processing Record 33 of Set 10 | port keats
# Processing Record 34 of Set 10 | bethel
# Processing Record 35 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 10 | tagusao
# Processing Record 37 of Set 10 | gravdal
# Processing Record 38 of Set 10 | manzhouli
# Processing Record 39 of Set 10 | novobelokatay
# Processing Record 40 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 10 | marfino
# Processing Record 42 of Set 10 | marstal
# Processing Record 43 of Set 10 | aguimes
# Processing Record 44 of Set 10 | nicoya
# Processing Record 45 of Set 10 | baillif
# Processing Record 46 of Set 10 | axim
# Processing Record 47 of Set 10 | harper
# Processing Record 48 of Set 10 | kargasok
# Processing Record 49 of Set 10 | qabis
# City not found. Skipping...
# Processing Record 50 of Set 10 | sakakah
# Processing Record 1 of Set 11 | pishin
# Processing Record 2 of Set 11 | andros town
# Processing Record 3 of Set 11 | santa ana
# Processing Record 4 of Set 11 | aksarka
# Processing Record 5 of Set 11 | fort nelson
# Processing Record 6 of Set 11 | tafalla
# Processing Record 7 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 11 | lianran
# Processing Record 9 of Set 11 | gulabpura
# Processing Record 10 of Set 11 | miramar
# Processing Record 11 of Set 11 | lavrentiya
# Processing Record 12 of Set 11 | mangan
# Processing Record 13 of Set 11 | yerbogachen
# Processing Record 14 of Set 11 | pavlodar
# Processing Record 15 of Set 11 | skibbereen
# Processing Record 16 of Set 11 | rozivka
# Processing Record 17 of Set 11 | sao joao da barra
# Processing Record 18 of Set 11 | iwaki
# Processing Record 19 of Set 11 | chapais
# Processing Record 20 of Set 11 | bellevue
# Processing Record 21 of Set 11 | grand forks
# Processing Record 22 of Set 11 | nyurba
# Processing Record 23 of Set 11 | noumea
# Processing Record 24 of Set 11 | milkovo
# Processing Record 25 of Set 11 | charagua
# Processing Record 26 of Set 11 | pedasi
# Processing Record 27 of Set 11 | uzumlu
# City not found. Skipping...
# Processing Record 28 of Set 11 | bengkulu
# Processing Record 29 of Set 11 | salihli
# Processing Record 30 of Set 11 | narrabri
# Processing Record 31 of Set 11 | mount isa
# Processing Record 32 of Set 11 | touros
# Processing Record 33 of Set 11 | urengoy
# Processing Record 34 of Set 11 | san carlos de bariloche
# Processing Record 35 of Set 11 | aldama
# Processing Record 36 of Set 11 | paris
# Processing Record 37 of Set 11 | tromso
# Processing Record 38 of Set 11 | mulchen
# Processing Record 39 of Set 11 | abu samrah
# Processing Record 40 of Set 11 | palmas bellas
# Processing Record 41 of Set 11 | kharp
# Processing Record 42 of Set 11 | north bend
# Processing Record 43 of Set 11 | coahuayana
# Processing Record 44 of Set 11 | poronaysk
# Processing Record 45 of Set 11 | artyom
# Processing Record 46 of Set 11 | sorong
# Processing Record 47 of Set 11 | poshekhonye
# Processing Record 48 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 49 of Set 11 | kailua
# Processing Record 50 of Set 11 | butwal
# Processing Record 1 of Set 12 | mweka
# Processing Record 2 of Set 12 | tefe
# Processing Record 3 of Set 12 | san lazaro
# Processing Record 4 of Set 12 | antigonish
# Processing Record 5 of Set 12 | mariestad
# Processing Record 6 of Set 12 | tambovka
# Processing Record 7 of Set 12 | rio gallegos
# Processing Record 8 of Set 12 | pekin
# Processing Record 9 of Set 12 | suchiapa
# Processing Record 10 of Set 12 | machinga
# Processing Record 11 of Set 12 | port said
# Processing Record 12 of Set 12 | bosaso
# Processing Record 13 of Set 12 | vila franca do campo
# Processing Record 14 of Set 12 | brae
# Processing Record 15 of Set 12 | yadgir
# Processing Record 16 of Set 12 | mangrol
# Processing Record 17 of Set 12 | rotifunk
# Processing Record 18 of Set 12 | stornoway
# Processing Record 19 of Set 12 | maceio
# Processing Record 20 of Set 12 | ginir
# Processing Record 21 of Set 12 | ewa beach
# Processing Record 22 of Set 12 | marawi
# Processing Record 23 of Set 12 | rantauprapat
# Processing Record 24 of Set 12 | lock haven
# Processing Record 25 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 12 | solomenskoye
# Processing Record 27 of Set 12 | riverton
# Processing Record 28 of Set 12 | barra do garcas
# Processing Record 29 of Set 12 | conakry
# Processing Record 30 of Set 12 | ulladulla
# Processing Record 31 of Set 12 | saint combs
# City not found. Skipping...
# Processing Record 32 of Set 12 | ugoofaaru
# Processing Record 33 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 12 | taltal
# Processing Record 35 of Set 12 | trairi
# Processing Record 36 of Set 12 | bamako
# Processing Record 37 of Set 12 | conceicao do araguaia
# Processing Record 38 of Set 12 | calumet city
# Processing Record 39 of Set 12 | lazaro cardenas
# Processing Record 40 of Set 12 | nizwa
# Processing Record 41 of Set 12 | svetlyy
# Processing Record 42 of Set 12 | plettenberg bay
# Processing Record 43 of Set 12 | kenai
# Processing Record 44 of Set 12 | marzuq
# Processing Record 45 of Set 12 | amahai
# Processing Record 46 of Set 12 | marinette
# Processing Record 47 of Set 12 | kamaishi
# Processing Record 48 of Set 12 | cabra
# Processing Record 49 of Set 12 | sao jose da coroa grande
# Processing Record 50 of Set 12 | azar shahr
# City not found. Skipping...
# Processing Record 1 of Set 13 | henties bay
# Processing Record 2 of Set 13 | karpogory
# Processing Record 3 of Set 13 | saldanha
# Processing Record 4 of Set 13 | florence
# Processing Record 5 of Set 13 | malangwa
# Processing Record 6 of Set 13 | bucak
# Processing Record 7 of Set 13 | el sauce
# Processing Record 8 of Set 13 | faya
# Processing Record 9 of Set 13 | ust-nera
# Processing Record 10 of Set 13 | loubomo
# Processing Record 11 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 13 | vanavara
# Processing Record 13 of Set 13 | urumqi
# Processing Record 14 of Set 13 | muscat
# Processing Record 15 of Set 13 | sala
# Processing Record 16 of Set 13 | toora-khem
# Processing Record 17 of Set 13 | san andres
# Processing Record 18 of Set 13 | itoman
# Processing Record 19 of Set 13 | tumpat
# Processing Record 20 of Set 13 | lubben
# Processing Record 21 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 13 | port augusta
# Processing Record 23 of Set 13 | yar-sale
# Processing Record 24 of Set 13 | tombouctou
# Processing Record 25 of Set 13 | sechura
# Processing Record 26 of Set 13 | te anau
# Processing Record 27 of Set 13 | iquique
# Processing Record 28 of Set 13 | alexandria
# Processing Record 29 of Set 13 | ahipara
# Processing Record 30 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 13 | goderich
# Processing Record 32 of Set 13 | ilinge
# Processing Record 33 of Set 13 | nambour
# Processing Record 34 of Set 13 | irati
# Processing Record 35 of Set 13 | bansi
# Processing Record 36 of Set 13 | shubarkuduk
# Processing Record 37 of Set 13 | obo
# Processing Record 38 of Set 13 | saint-georges
# Processing Record 39 of Set 13 | igrim
# Processing Record 40 of Set 13 | altavas
# Processing Record 41 of Set 13 | tevaitoa
# Processing Record 42 of Set 13 | trogir
# Processing Record 43 of Set 13 | kamyzyak
# Processing Record 44 of Set 13 | marshfield
# Processing Record 45 of Set 13 | milton keynes
# Processing Record 46 of Set 13 | mossendjo
# Processing Record 47 of Set 13 | bonthe
# Processing Record 48 of Set 13 | havre-saint-pierre
# Processing Record 49 of Set 13 | angoche
# Processing Record 50 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 14 | port-gentil
# Processing Record 2 of Set 14 | palanpur
# Processing Record 3 of Set 14 | samana
# Processing Record 4 of Set 14 | carballo
# Processing Record 5 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 14 | tutoia
# Processing Record 7 of Set 14 | rexburg
# Processing Record 8 of Set 14 | waitati
# Processing Record 9 of Set 14 | northam
# Processing Record 10 of Set 14 | vanimo
# Processing Record 11 of Set 14 | aripuana
# Processing Record 12 of Set 14 | kidal
# Processing Record 13 of Set 14 | sisimiut
# Processing Record 14 of Set 14 | nantucket
# Processing Record 15 of Set 14 | yanam
# Processing Record 16 of Set 14 | bukachacha
# Processing Record 17 of Set 14 | havoysund
# Processing Record 18 of Set 14 | tara
# Processing Record 19 of Set 14 | olafsvik
# Processing Record 20 of Set 14 | puro
# Processing Record 21 of Set 14 | coquimbo
# Processing Record 22 of Set 14 | bahia de caraquez
# Processing Record 23 of Set 14 | bereda
# Processing Record 24 of Set 14 | mehamn
# Processing Record 25 of Set 14 | san francisco
# Processing Record 26 of Set 14 | tommot
# Processing Record 27 of Set 14 | srednekolymsk
# Processing Record 28 of Set 14 | gejiu
# Processing Record 29 of Set 14 | maniitsoq
# Processing Record 30 of Set 14 | dutlwe
# Processing Record 31 of Set 14 | presidencia roque saenz pena
# Processing Record 32 of Set 14 | ban nahin
# Processing Record 33 of Set 14 | ziarat
# Processing Record 34 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 14 | san-pedro
# Processing Record 36 of Set 14 | settimo torinese
# Processing Record 37 of Set 14 | atkinson
# Processing Record 38 of Set 14 | grand-santi
# Processing Record 39 of Set 14 | fare
# Processing Record 40 of Set 14 | price
# Processing Record 41 of Set 14 | bambanglipuro
# Processing Record 42 of Set 14 | verkhoyansk
# Processing Record 43 of Set 14 | port hardy
# Processing Record 44 of Set 14 | chimbote
# Processing Record 45 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 46 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 14 | saint-pierre
# Processing Record 48 of Set 14 | non sung
# Processing Record 49 of Set 14 | the pas
# Processing Record 50 of Set 14 | isangel
# Processing Record 1 of Set 15 | ibanda
# Processing Record 2 of Set 15 | porto novo
# Processing Record 3 of Set 15 | fonte boa
# Processing Record 4 of Set 15 | gigmoto
# Processing Record 5 of Set 15 | karratha
# Processing Record 6 of Set 15 | amazar
# Processing Record 7 of Set 15 | bairiki
# Processing Record 8 of Set 15 | grindavik
# Processing Record 9 of Set 15 | sysert
# Processing Record 10 of Set 15 | mandurah
# Processing Record 11 of Set 15 | tual
# Processing Record 12 of Set 15 | kosice
# Processing Record 13 of Set 15 | straumen
# Processing Record 14 of Set 15 | waiuku
# Processing Record 15 of Set 15 | nybro
# Processing Record 16 of Set 15 | arman
# Processing Record 17 of Set 15 | itzehoe
# Processing Record 18 of Set 15 | guidonia
# Processing Record 19 of Set 15 | leshukonskoye
# Processing Record 20 of Set 15 | rancho palos verdes
# Processing Record 21 of Set 15 | ketchikan
# Processing Record 22 of Set 15 | high level
# Processing Record 23 of Set 15 | bereznik
# Processing Record 24 of Set 15 | nouakchott
# Processing Record 25 of Set 15 | itainopolis
# Processing Record 26 of Set 15 | sangre grande
# Processing Record 27 of Set 15 | monywa
# Processing Record 28 of Set 15 | makaha
# Processing Record 29 of Set 15 | taitung
# Processing Record 30 of Set 15 | kibala
# Processing Record 31 of Set 15 | camocim
# Processing Record 32 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 33 of Set 15 | wangqing
# Processing Record 34 of Set 15 | verishen
# Processing Record 35 of Set 15 | mahajanga
# Processing Record 36 of Set 15 | galle
# Processing Record 37 of Set 15 | listvyagi
# Processing Record 38 of Set 15 | baykit
# Processing Record 39 of Set 15 | ankara
# Processing Record 40 of Set 15 | bull savanna
# Processing Record 41 of Set 15 | makasar
# Processing Record 42 of Set 15 | mayumba
# Processing Record 43 of Set 15 | tveit
# Processing Record 44 of Set 15 | romitan
# Processing Record 45 of Set 15 | jensen beach
# Processing Record 46 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 15 | avera
# Processing Record 48 of Set 15 | hervey bay
# Processing Record 49 of Set 15 | chiang khong
# Processing Record 50 of Set 15 | paita
# Processing Record 1 of Set 16 | thohoyandou
# Processing Record 2 of Set 16 | tanete
# Processing Record 3 of Set 16 | aklavik
# Processing Record 4 of Set 16 | susangerd
# Processing Record 5 of Set 16 | ankazobe
# Processing Record 6 of Set 16 | bristol
# Processing Record 7 of Set 16 | vostok
# Processing Record 8 of Set 16 | othonoi
# City not found. Skipping...
# Processing Record 9 of Set 16 | wolmaranstad
# City not found. Skipping...
# Processing Record 10 of Set 16 | male
# Processing Record 11 of Set 16 | san luis rio colorado
# Processing Record 12 of Set 16 | ajuchitlan
# Processing Record 13 of Set 16 | davila
# Processing Record 14 of Set 16 | sochi
# Processing Record 15 of Set 16 | port moresby
# Processing Record 16 of Set 16 | nyagan
# Processing Record 17 of Set 16 | nemuro
# Processing Record 18 of Set 16 | japura
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Check length
len(city_data)
# Out:
# 704

# %%
#Create dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Punta Arenas      CL -53.1500  -70.9167     48.20        57
# 1                  Morondava      MG -20.2833   44.2833     78.87        80
# 2                        Vao      NC -22.6667  167.4833     75.02        81
# 3                     Padina      RS  45.1181   20.7272     42.01       100
# 4                   Araouane      ML  18.9048   -3.5265     90.86         8
# 5               Saint George      US  37.1041 -113.5841     69.01        19
# 6                     Albany      US  42.6001  -73.9662     71.60        34
# 7                Tuktoyaktuk      CA  69.4541 -133.0374     10.40        92
# 8  Doctor Juan Manuel Frutos      PY -25.3667  -55.8000     88.68        38
# 9                  Dyersburg      US  36.0345  -89.3856     59.00        67
#
#    Cloudiness  Wind Speed Current Description                 Date
# 0          20       27.63          few clouds  2021-04-14 19:11:05
# 1           1        5.19       moderate rain  2021-04-14 19:11:06
# 2         100       22.17     overcast clouds  2021-04-14 19:11:06
# 3          75        6.91          light rain  2021-04-14 19:11:06
# 4           0        0.65           clear sky  2021-04-14 19:11:07
# 5           1       11.50           clear sky  2021-04-14 19:09:11
# 6          75        1.41       broken clouds  2021-04-14 19:07:00
# 7          75        5.75       broken clouds  2021-04-14 19:11:07
# 8          63        4.32       broken clouds  2021-04-14 19:11:08
# 9          90        9.22     overcast clouds  2021-04-14 19:11:08

# %%
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Cloudiness  \
# 0               Punta Arenas      CL -53.1500  -70.9167     48.20          20
# 1                  Morondava      MG -20.2833   44.2833     78.87           1
# 2                        Vao      NC -22.6667  167.4833     75.02         100
# 3                     Padina      RS  45.1181   20.7272     42.01          75
# 4                   Araouane      ML  18.9048   -3.5265     90.86           0
# 5               Saint George      US  37.1041 -113.5841     69.01           1
# 6                     Albany      US  42.6001  -73.9662     71.60          75
# 7                Tuktoyaktuk      CA  69.4541 -133.0374     10.40          75
# 8  Doctor Juan Manuel Frutos      PY -25.3667  -55.8000     88.68          63
# 9                  Dyersburg      US  36.0345  -89.3856     59.00          90
#
#    Wind Speed Current Description
# 0       27.63          few clouds
# 1        5.19       moderate rain
# 2       22.17     overcast clouds
# 3        6.91          light rain
# 4        0.65           clear sky
# 5       11.50           clear sky
# 6        1.41       broken clouds
# 7        5.75       broken clouds
# 8        4.32       broken clouds
# 9        9.22     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
