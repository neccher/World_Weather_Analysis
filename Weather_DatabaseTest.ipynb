# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create set of random longitudes and latitudes
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add longs and lats to list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 727

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#Loop through all cities in list
for i, city in enumerate(cities):
    
    #Group cities in blocks of 50
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create endpoint URLwith each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log URL, record, and set numbers and city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to record_count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | wajima
# Processing Record 3 of Set 1 | hazorasp
# Processing Record 4 of Set 1 | hami
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | saldanha
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | denizli
# Processing Record 10 of Set 1 | pisco
# Processing Record 11 of Set 1 | gamba
# Processing Record 12 of Set 1 | acapulco
# Processing Record 13 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | ancud
# Processing Record 17 of Set 1 | neiafu
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | te anau
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | aberdeen
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | mandera
# Processing Record 24 of Set 1 | orasac
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | richards bay
# Processing Record 27 of Set 1 | norman wells
# Processing Record 28 of Set 1 | sucua
# Processing Record 29 of Set 1 | katsuura
# Processing Record 30 of Set 1 | dodoma
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | tuatapere
# Processing Record 33 of Set 1 | trinidad
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | sexsmith
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | bagdarin
# Processing Record 41 of Set 1 | vila velha
# Processing Record 42 of Set 1 | korla
# Processing Record 43 of Set 1 | lagoa
# Processing Record 44 of Set 1 | kalanchak
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | honiara
# Processing Record 47 of Set 1 | bonavista
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | ostrovnoy
# Processing Record 2 of Set 2 | roma
# Processing Record 3 of Set 2 | quatre cocos
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | rawson
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | dunedin
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | semirom
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | ekibastuz
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | dunmore town
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | gizo
# Processing Record 17 of Set 2 | leninsk
# Processing Record 18 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 2 | hamilton
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | acari
# Processing Record 24 of Set 2 | namibe
# Processing Record 25 of Set 2 | coquimbo
# Processing Record 26 of Set 2 | kilindoni
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | saint-joseph
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | yueyang
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | clyde river
# Processing Record 33 of Set 2 | airai
# Processing Record 34 of Set 2 | ilulissat
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | bolshaya rechka
# Processing Record 37 of Set 2 | bathsheba
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | viedma
# Processing Record 40 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | san jose
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | surgana
# Processing Record 46 of Set 2 | mpongwe
# Processing Record 47 of Set 2 | sept-iles
# Processing Record 48 of Set 2 | nuristan
# Processing Record 49 of Set 2 | mogochin
# City not found. Skipping...
# Processing Record 50 of Set 2 | kuryk
# Processing Record 1 of Set 3 | svetlaya
# Processing Record 2 of Set 3 | brae
# Processing Record 3 of Set 3 | kargat
# Processing Record 4 of Set 3 | natal
# Processing Record 5 of Set 3 | sao joao da barra
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | saint-leu
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | carballo
# Processing Record 10 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 3 | kaitangata
# Processing Record 12 of Set 3 | hirara
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | maarianhamina
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | bolonchen
# City not found. Skipping...
# Processing Record 18 of Set 3 | georgetown
# Processing Record 19 of Set 3 | mount gambier
# Processing Record 20 of Set 3 | barrow
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | jagannathpur
# Processing Record 23 of Set 3 | vaini
# Processing Record 24 of Set 3 | srednekolymsk
# Processing Record 25 of Set 3 | dwarka
# Processing Record 26 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 3 | kuching
# Processing Record 28 of Set 3 | kayerkan
# Processing Record 29 of Set 3 | carutapera
# Processing Record 30 of Set 3 | deputatskiy
# Processing Record 31 of Set 3 | provideniya
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | piacabucu
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | beringovskiy
# Processing Record 37 of Set 3 | erenhot
# Processing Record 38 of Set 3 | palmer
# Processing Record 39 of Set 3 | le port
# Processing Record 40 of Set 3 | raymondville
# Processing Record 41 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 3 | grudziadz
# Processing Record 43 of Set 3 | aklavik
# Processing Record 44 of Set 3 | qeshm
# Processing Record 45 of Set 3 | poum
# Processing Record 46 of Set 3 | sao felix do xingu
# Processing Record 47 of Set 3 | maceio
# Processing Record 48 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 3 | kupang
# Processing Record 50 of Set 3 | ndele
# Processing Record 1 of Set 4 | butaritari
# Processing Record 2 of Set 4 | cidreira
# Processing Record 3 of Set 4 | cockburn town
# Processing Record 4 of Set 4 | talara
# Processing Record 5 of Set 4 | praia
# Processing Record 6 of Set 4 | la rioja
# Processing Record 7 of Set 4 | pevek
# Processing Record 8 of Set 4 | san cristobal
# Processing Record 9 of Set 4 | jumla
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | aleksandrov gay
# Processing Record 12 of Set 4 | asau
# Processing Record 13 of Set 4 | beaver dam
# Processing Record 14 of Set 4 | saint george
# Processing Record 15 of Set 4 | nanortalik
# Processing Record 16 of Set 4 | puerto escondido
# Processing Record 17 of Set 4 | the valley
# Processing Record 18 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 4 | manggar
# Processing Record 20 of Set 4 | weligama
# Processing Record 21 of Set 4 | villanueva de cordoba
# Processing Record 22 of Set 4 | mocuba
# Processing Record 23 of Set 4 | longyearbyen
# Processing Record 24 of Set 4 | upernavik
# Processing Record 25 of Set 4 | pringsewu
# Processing Record 26 of Set 4 | hithadhoo
# Processing Record 27 of Set 4 | iberia
# Processing Record 28 of Set 4 | esperance
# Processing Record 29 of Set 4 | nauta
# Processing Record 30 of Set 4 | kingaroy
# Processing Record 31 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 4 | oranjemund
# Processing Record 33 of Set 4 | wabag
# Processing Record 34 of Set 4 | dikson
# Processing Record 35 of Set 4 | duz
# City not found. Skipping...
# Processing Record 36 of Set 4 | manisa
# Processing Record 37 of Set 4 | manhattan
# Processing Record 38 of Set 4 | vestmanna
# Processing Record 39 of Set 4 | bengkulu
# Processing Record 40 of Set 4 | kodiak
# Processing Record 41 of Set 4 | bambous virieux
# Processing Record 42 of Set 4 | general roca
# Processing Record 43 of Set 4 | barranca
# Processing Record 44 of Set 4 | ugoofaaru
# Processing Record 45 of Set 4 | pafos
# Processing Record 46 of Set 4 | izhma
# Processing Record 47 of Set 4 | berlevag
# Processing Record 48 of Set 4 | creel
# Processing Record 49 of Set 4 | kouroussa
# Processing Record 50 of Set 4 | aswan
# Processing Record 1 of Set 5 | leningradskiy
# Processing Record 2 of Set 5 | mantua
# Processing Record 3 of Set 5 | touros
# Processing Record 4 of Set 5 | luwuk
# Processing Record 5 of Set 5 | ilabaya
# Processing Record 6 of Set 5 | zhigansk
# Processing Record 7 of Set 5 | lampazos de naranjo
# Processing Record 8 of Set 5 | nabire
# Processing Record 9 of Set 5 | port-cartier
# Processing Record 10 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 5 | khatanga
# Processing Record 12 of Set 5 | usinsk
# Processing Record 13 of Set 5 | alofi
# Processing Record 14 of Set 5 | bafra
# Processing Record 15 of Set 5 | komsomolskiy
# Processing Record 16 of Set 5 | harper
# Processing Record 17 of Set 5 | east foothills
# Processing Record 18 of Set 5 | eseka
# Processing Record 19 of Set 5 | odweyne
# Processing Record 20 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 5 | boone
# Processing Record 22 of Set 5 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 23 of Set 5 | tessalit
# Processing Record 24 of Set 5 | bontang
# Processing Record 25 of Set 5 | hay river
# Processing Record 26 of Set 5 | znamenskoye
# Processing Record 27 of Set 5 | skovorodino
# Processing Record 28 of Set 5 | grindavik
# Processing Record 29 of Set 5 | homer
# Processing Record 30 of Set 5 | zhuhai
# Processing Record 31 of Set 5 | makakilo city
# Processing Record 32 of Set 5 | hanamaki
# Processing Record 33 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 5 | kudat
# Processing Record 35 of Set 5 | chiang klang
# Processing Record 36 of Set 5 | broken hill
# Processing Record 37 of Set 5 | nenjiang
# Processing Record 38 of Set 5 | barentu
# Processing Record 39 of Set 5 | burevestnik
# Processing Record 40 of Set 5 | kavieng
# Processing Record 41 of Set 5 | hunterville
# Processing Record 42 of Set 5 | sao domingos
# Processing Record 43 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 5 | sakakah
# Processing Record 45 of Set 5 | udachnyy
# Processing Record 46 of Set 5 | shimoda
# Processing Record 47 of Set 5 | red deer
# Processing Record 48 of Set 5 | yar-sale
# Processing Record 49 of Set 5 | hampton
# Processing Record 50 of Set 5 | pangnirtung
# Processing Record 1 of Set 6 | swan hill
# Processing Record 2 of Set 6 | port lincoln
# Processing Record 3 of Set 6 | nyurba
# Processing Record 4 of Set 6 | along
# Processing Record 5 of Set 6 | salalah
# Processing Record 6 of Set 6 | ginir
# Processing Record 7 of Set 6 | marolambo
# Processing Record 8 of Set 6 | porto novo
# Processing Record 9 of Set 6 | itaquaquecetuba
# Processing Record 10 of Set 6 | lavrentiya
# Processing Record 11 of Set 6 | takoradi
# Processing Record 12 of Set 6 | lander
# Processing Record 13 of Set 6 | karpathos
# Processing Record 14 of Set 6 | tura
# Processing Record 15 of Set 6 | bethel
# Processing Record 16 of Set 6 | lorica
# Processing Record 17 of Set 6 | samarai
# Processing Record 18 of Set 6 | magdalena
# Processing Record 19 of Set 6 | banamba
# Processing Record 20 of Set 6 | campo maior
# Processing Record 21 of Set 6 | ambon
# Processing Record 22 of Set 6 | hachinohe
# Processing Record 23 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 6 | vardo
# Processing Record 25 of Set 6 | pochutla
# Processing Record 26 of Set 6 | manuk mangkaw
# Processing Record 27 of Set 6 | klaksvik
# Processing Record 28 of Set 6 | abu dhabi
# Processing Record 29 of Set 6 | gazli
# Processing Record 30 of Set 6 | portland
# Processing Record 31 of Set 6 | wanlaweyn
# Processing Record 32 of Set 6 | cabo san lucas
# Processing Record 33 of Set 6 | fort nelson
# Processing Record 34 of Set 6 | nouadhibou
# Processing Record 35 of Set 6 | tambacounda
# Processing Record 36 of Set 6 | mayumba
# Processing Record 37 of Set 6 | dekar
# Processing Record 38 of Set 6 | osterburg
# Processing Record 39 of Set 6 | ibra
# Processing Record 40 of Set 6 | bria
# Processing Record 41 of Set 6 | ust-maya
# Processing Record 42 of Set 6 | pemba
# Processing Record 43 of Set 6 | itoman
# Processing Record 44 of Set 6 | saint anthony
# Processing Record 45 of Set 6 | wajir
# Processing Record 46 of Set 6 | college
# Processing Record 47 of Set 6 | carnarvon
# Processing Record 48 of Set 6 | whyalla
# Processing Record 49 of Set 6 | camacha
# Processing Record 50 of Set 6 | north bend
# Processing Record 1 of Set 7 | krasnyy yar
# Processing Record 2 of Set 7 | cheyenne
# Processing Record 3 of Set 7 | kayfan
# City not found. Skipping...
# Processing Record 4 of Set 7 | saint-georges
# Processing Record 5 of Set 7 | kuji
# Processing Record 6 of Set 7 | urgut
# Processing Record 7 of Set 7 | sao filipe
# Processing Record 8 of Set 7 | pundaguitan
# Processing Record 9 of Set 7 | slave lake
# Processing Record 10 of Set 7 | severobaykalsk
# Processing Record 11 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 7 | alice springs
# Processing Record 13 of Set 7 | ponazyrevo
# Processing Record 14 of Set 7 | maldonado
# Processing Record 15 of Set 7 | catio
# Processing Record 16 of Set 7 | governador valadares
# Processing Record 17 of Set 7 | vila franca do campo
# Processing Record 18 of Set 7 | port macquarie
# Processing Record 19 of Set 7 | broome
# Processing Record 20 of Set 7 | saint simons
# Processing Record 21 of Set 7 | presidencia roque saenz pena
# Processing Record 22 of Set 7 | whithorn
# Processing Record 23 of Set 7 | saskylakh
# Processing Record 24 of Set 7 | zyryanovsk
# Processing Record 25 of Set 7 | lorengau
# Processing Record 26 of Set 7 | sovetskiy
# Processing Record 27 of Set 7 | sur
# Processing Record 28 of Set 7 | sarangani
# Processing Record 29 of Set 7 | vestmannaeyjar
# Processing Record 30 of Set 7 | nova olinda do norte
# Processing Record 31 of Set 7 | jackson
# Processing Record 32 of Set 7 | appingedam
# Processing Record 33 of Set 7 | prince rupert
# Processing Record 34 of Set 7 | el alto
# Processing Record 35 of Set 7 | gojra
# Processing Record 36 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 7 | buala
# Processing Record 38 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 7 | ahipara
# Processing Record 40 of Set 7 | dumai
# Processing Record 41 of Set 7 | margate
# Processing Record 42 of Set 7 | gravdal
# Processing Record 43 of Set 7 | torbay
# Processing Record 44 of Set 7 | menomonie
# Processing Record 45 of Set 7 | agadir
# Processing Record 46 of Set 7 | logan
# Processing Record 47 of Set 7 | birjand
# Processing Record 48 of Set 7 | souillac
# Processing Record 49 of Set 7 | tabas
# Processing Record 50 of Set 7 | novyy nekouz
# Processing Record 1 of Set 8 | avarua
# Processing Record 2 of Set 8 | siniscola
# Processing Record 3 of Set 8 | comodoro rivadavia
# Processing Record 4 of Set 8 | guazapa
# Processing Record 5 of Set 8 | marystown
# Processing Record 6 of Set 8 | asyut
# Processing Record 7 of Set 8 | maple creek
# Processing Record 8 of Set 8 | narsaq
# Processing Record 9 of Set 8 | sainte-maxime
# Processing Record 10 of Set 8 | casma
# Processing Record 11 of Set 8 | linjiang
# Processing Record 12 of Set 8 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 13 of Set 8 | vianopolis
# Processing Record 14 of Set 8 | voznesenye
# Processing Record 15 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 8 | guangyuan
# Processing Record 17 of Set 8 | bayonet point
# Processing Record 18 of Set 8 | milledgeville
# Processing Record 19 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 8 | madawaska
# Processing Record 21 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 8 | kavaratti
# Processing Record 23 of Set 8 | matagami
# Processing Record 24 of Set 8 | ukiah
# Processing Record 25 of Set 8 | rocha
# Processing Record 26 of Set 8 | ipora
# Processing Record 27 of Set 8 | vidim
# Processing Record 28 of Set 8 | dudinka
# Processing Record 29 of Set 8 | qaqortoq
# Processing Record 30 of Set 8 | kokrajhar
# Processing Record 31 of Set 8 | bubaque
# Processing Record 32 of Set 8 | meulaboh
# Processing Record 33 of Set 8 | codrington
# Processing Record 34 of Set 8 | carndonagh
# Processing Record 35 of Set 8 | mandalgovi
# Processing Record 36 of Set 8 | adiake
# Processing Record 37 of Set 8 | manzhouli
# Processing Record 38 of Set 8 | sola
# Processing Record 39 of Set 8 | yulara
# Processing Record 40 of Set 8 | sabang
# Processing Record 41 of Set 8 | wattegama
# Processing Record 42 of Set 8 | kincardine
# Processing Record 43 of Set 8 | beitbridge
# Processing Record 44 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 8 | ubon ratchathani
# Processing Record 46 of Set 8 | rome
# Processing Record 47 of Set 8 | tuktoyaktuk
# Processing Record 48 of Set 8 | elliot lake
# Processing Record 49 of Set 8 | santa isabel do rio negro
# Processing Record 50 of Set 8 | boras
# Processing Record 1 of Set 9 | cascais
# Processing Record 2 of Set 9 | jalu
# Processing Record 3 of Set 9 | guerrero negro
# Processing Record 4 of Set 9 | san patricio
# Processing Record 5 of Set 9 | ereymentau
# Processing Record 6 of Set 9 | sorland
# Processing Record 7 of Set 9 | gladstone
# Processing Record 8 of Set 9 | mitchell
# Processing Record 9 of Set 9 | zaraza
# Processing Record 10 of Set 9 | mana
# Processing Record 11 of Set 9 | ler
# Processing Record 12 of Set 9 | kahului
# Processing Record 13 of Set 9 | charters towers
# Processing Record 14 of Set 9 | chester
# Processing Record 15 of Set 9 | tual
# Processing Record 16 of Set 9 | colquiri
# Processing Record 17 of Set 9 | simpang
# Processing Record 18 of Set 9 | honningsvag
# Processing Record 19 of Set 9 | ponnani
# Processing Record 20 of Set 9 | salinas
# Processing Record 21 of Set 9 | worcester
# Processing Record 22 of Set 9 | aktash
# Processing Record 23 of Set 9 | rabo de peixe
# Processing Record 24 of Set 9 | luanda
# Processing Record 25 of Set 9 | pangai
# Processing Record 26 of Set 9 | pemangkat
# Processing Record 27 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 28 of Set 9 | faya
# Processing Record 29 of Set 9 | catia la mar
# Processing Record 30 of Set 9 | saint-augustin
# Processing Record 31 of Set 9 | santa rosa
# Processing Record 32 of Set 9 | mezen
# Processing Record 33 of Set 9 | yeppoon
# Processing Record 34 of Set 9 | kastamonu
# Processing Record 35 of Set 9 | marcovia
# Processing Record 36 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 37 of Set 9 | whitianga
# Processing Record 38 of Set 9 | oyon
# Processing Record 39 of Set 9 | constitucion
# Processing Record 40 of Set 9 | chingirlau
# Processing Record 41 of Set 9 | kamenka
# Processing Record 42 of Set 9 | farafangana
# Processing Record 43 of Set 9 | conakry
# Processing Record 44 of Set 9 | jardim
# Processing Record 45 of Set 9 | hitoyoshi
# Processing Record 46 of Set 9 | tower
# Processing Record 47 of Set 9 | sundargarh
# Processing Record 48 of Set 9 | nikolskoye
# Processing Record 49 of Set 9 | evensk
# Processing Record 50 of Set 9 | olinda
# Processing Record 1 of Set 10 | itapetinga
# Processing Record 2 of Set 10 | galle
# Processing Record 3 of Set 10 | kudahuvadhoo
# Processing Record 4 of Set 10 | mecca
# Processing Record 5 of Set 10 | imeni stepana razina
# Processing Record 6 of Set 10 | necochea
# Processing Record 7 of Set 10 | belovo
# Processing Record 8 of Set 10 | axim
# Processing Record 9 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 10 | sitka
# Processing Record 11 of Set 10 | dali
# Processing Record 12 of Set 10 | mareeba
# Processing Record 13 of Set 10 | placido de castro
# Processing Record 14 of Set 10 | nueva londres
# Processing Record 15 of Set 10 | santa maria
# Processing Record 16 of Set 10 | jining
# Processing Record 17 of Set 10 | black diamond
# Processing Record 18 of Set 10 | batemans bay
# Processing Record 19 of Set 10 | noumea
# Processing Record 20 of Set 10 | andenes
# Processing Record 21 of Set 10 | buluang
# Processing Record 22 of Set 10 | christchurch
# Processing Record 23 of Set 10 | sayat
# Processing Record 24 of Set 10 | grafton
# Processing Record 25 of Set 10 | ino
# Processing Record 26 of Set 10 | corner brook
# Processing Record 27 of Set 10 | havre-saint-pierre
# Processing Record 28 of Set 10 | padang
# Processing Record 29 of Set 10 | yuzhno-kurilsk
# Processing Record 30 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 10 | palkaka
# City not found. Skipping...
# Processing Record 32 of Set 10 | roald
# Processing Record 33 of Set 10 | coruripe
# Processing Record 34 of Set 10 | mayo
# Processing Record 35 of Set 10 | puerto madryn
# Processing Record 36 of Set 10 | huai mek
# Processing Record 37 of Set 10 | darnah
# Processing Record 38 of Set 10 | karratha
# Processing Record 39 of Set 10 | dosso
# Processing Record 40 of Set 10 | bairiki
# Processing Record 41 of Set 10 | judenburg
# Processing Record 42 of Set 10 | pucallpa
# Processing Record 43 of Set 10 | puerto leguizamo
# Processing Record 44 of Set 10 | uaua
# Processing Record 45 of Set 10 | floresta
# Processing Record 46 of Set 10 | hovd
# Processing Record 47 of Set 10 | den helder
# Processing Record 48 of Set 10 | cayenne
# Processing Record 49 of Set 10 | talcahuano
# Processing Record 50 of Set 10 | wamba
# Processing Record 1 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 11 | kalmunai
# Processing Record 3 of Set 11 | paamiut
# Processing Record 4 of Set 11 | youkounkoun
# Processing Record 5 of Set 11 | kawalu
# Processing Record 6 of Set 11 | vao
# Processing Record 7 of Set 11 | la peca
# Processing Record 8 of Set 11 | ulaanbaatar
# Processing Record 9 of Set 11 | alihe
# Processing Record 10 of Set 11 | rio gallegos
# Processing Record 11 of Set 11 | hofn
# Processing Record 12 of Set 11 | jerome
# Processing Record 13 of Set 11 | hokitika
# Processing Record 14 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 11 | eureka
# Processing Record 16 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 11 | bhakkar
# Processing Record 18 of Set 11 | anderson
# Processing Record 19 of Set 11 | igbo ora
# Processing Record 20 of Set 11 | kununurra
# Processing Record 21 of Set 11 | mazamari
# Processing Record 22 of Set 11 | nobeoka
# Processing Record 23 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 24 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 11 | inirida
# Processing Record 26 of Set 11 | catamarca
# Processing Record 27 of Set 11 | port-gentil
# Processing Record 28 of Set 11 | rawah
# Processing Record 29 of Set 11 | polessk
# Processing Record 30 of Set 11 | kieta
# Processing Record 31 of Set 11 | skibbereen
# Processing Record 32 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 11 | suluq
# Processing Record 34 of Set 11 | rabaul
# Processing Record 35 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 36 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 11 | kapit
# Processing Record 38 of Set 11 | leeton
# Processing Record 39 of Set 11 | turukhansk
# Processing Record 40 of Set 11 | yen bai
# Processing Record 41 of Set 11 | grand-santi
# Processing Record 42 of Set 11 | okahandja
# Processing Record 43 of Set 11 | saravan
# Processing Record 44 of Set 11 | tigil
# Processing Record 45 of Set 11 | orchard homes
# Processing Record 46 of Set 11 | hindoria
# Processing Record 47 of Set 11 | unai
# Processing Record 48 of Set 11 | trairi
# Processing Record 49 of Set 11 | ponta delgada
# Processing Record 50 of Set 11 | bodden town
# Processing Record 1 of Set 12 | marsa matruh
# Processing Record 2 of Set 12 | haines junction
# Processing Record 3 of Set 12 | bannu
# Processing Record 4 of Set 12 | nicoya
# Processing Record 5 of Set 12 | kamaishi
# Processing Record 6 of Set 12 | pocone
# Processing Record 7 of Set 12 | fairbanks
# Processing Record 8 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 12 | qasigiannguit
# Processing Record 10 of Set 12 | baglan
# Processing Record 11 of Set 12 | nemuro
# Processing Record 12 of Set 12 | olafsvik
# Processing Record 13 of Set 12 | nelson bay
# Processing Record 14 of Set 12 | kem
# Processing Record 15 of Set 12 | hualmay
# Processing Record 16 of Set 12 | mendahara
# City not found. Skipping...
# Processing Record 17 of Set 12 | kirakira
# Processing Record 18 of Set 12 | segezha
# Processing Record 19 of Set 12 | esil
# Processing Record 20 of Set 12 | henties bay
# Processing Record 21 of Set 12 | acajutla
# Processing Record 22 of Set 12 | tamandare
# Processing Record 23 of Set 12 | taoudenni
# Processing Record 24 of Set 12 | riberalta
# Processing Record 25 of Set 12 | svetlyy
# Processing Record 26 of Set 12 | calvia
# Processing Record 27 of Set 12 | abay
# Processing Record 28 of Set 12 | malatya
# Processing Record 29 of Set 12 | vila
# Processing Record 30 of Set 12 | kendari
# Processing Record 31 of Set 12 | cartagena
# Processing Record 32 of Set 12 | yarmouth
# Processing Record 33 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 34 of Set 12 | goderich
# Processing Record 35 of Set 12 | plyussa
# Processing Record 36 of Set 12 | aksarka
# Processing Record 37 of Set 12 | sabancuy
# Processing Record 38 of Set 12 | acarau
# Processing Record 39 of Set 12 | biella
# Processing Record 40 of Set 12 | balkhash
# Processing Record 41 of Set 12 | kruisfontein
# Processing Record 42 of Set 12 | kerouane
# Processing Record 43 of Set 12 | uarini
# Processing Record 44 of Set 12 | cururupu
# Processing Record 45 of Set 12 | gazanjyk
# Processing Record 46 of Set 12 | asekeyevo
# Processing Record 47 of Set 12 | ust-tsilma
# Processing Record 48 of Set 12 | jiuquan
# Processing Record 49 of Set 12 | eregli
# Processing Record 50 of Set 12 | diamantina
# Processing Record 1 of Set 13 | ranghulu
# Processing Record 2 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 3 of Set 13 | ahuimanu
# Processing Record 4 of Set 13 | marienburg
# Processing Record 5 of Set 13 | sorong
# Processing Record 6 of Set 13 | bud
# Processing Record 7 of Set 13 | luderitz
# Processing Record 8 of Set 13 | ozinki
# Processing Record 9 of Set 13 | mapiripan
# Processing Record 10 of Set 13 | itarema
# Processing Record 11 of Set 13 | red bluff
# Processing Record 12 of Set 13 | churapcha
# Processing Record 13 of Set 13 | omsukchan
# Processing Record 14 of Set 13 | fortuna
# Processing Record 15 of Set 13 | katobu
# Processing Record 16 of Set 13 | hartford
# Processing Record 17 of Set 13 | timoteo
# Processing Record 18 of Set 13 | auki
# Processing Record 19 of Set 13 | altamont
# Processing Record 20 of Set 13 | nueva helvecia
# Processing Record 21 of Set 13 | wuda
# Processing Record 22 of Set 13 | lucea
# Processing Record 23 of Set 13 | pitimbu
# Processing Record 24 of Set 13 | gat
# Processing Record 25 of Set 13 | pontypool
# Processing Record 26 of Set 13 | bocas del toro
# Processing Record 27 of Set 13 | thinadhoo
# Processing Record 28 of Set 13 | muroto
# Processing Record 29 of Set 13 | mangrol
# Processing Record 30 of Set 13 | truro
# Processing Record 31 of Set 13 | tombouctou
# Processing Record 32 of Set 13 | myitkyina
# Processing Record 33 of Set 13 | cabinda
# Processing Record 34 of Set 13 | fairlie
# Processing Record 35 of Set 13 | inhambane
# Processing Record 36 of Set 13 | praya
# Processing Record 37 of Set 13 | ende
# Processing Record 38 of Set 13 | pervomayskoye
# Processing Record 39 of Set 13 | ossora
# Processing Record 40 of Set 13 | lamu
# Processing Record 41 of Set 13 | marsh harbour
# Processing Record 42 of Set 13 | bushehr
# Processing Record 43 of Set 13 | chapais
# Processing Record 44 of Set 13 | hervey bay
# Processing Record 45 of Set 13 | barcelona
# Processing Record 46 of Set 13 | vieques
# Processing Record 47 of Set 13 | vares
# Processing Record 48 of Set 13 | pokhara
# Processing Record 49 of Set 13 | manbij
# Processing Record 50 of Set 13 | rafraf
# Processing Record 1 of Set 14 | antalaha
# Processing Record 2 of Set 14 | grand gaube
# Processing Record 3 of Set 14 | celestun
# Processing Record 4 of Set 14 | agadez
# Processing Record 5 of Set 14 | buin
# Processing Record 6 of Set 14 | paka
# Processing Record 7 of Set 14 | krasnik
# Processing Record 8 of Set 14 | bang rakam
# Processing Record 9 of Set 14 | keflavik
# Processing Record 10 of Set 14 | namatanai
# Processing Record 11 of Set 14 | mondlo
# Processing Record 12 of Set 14 | doka
# Processing Record 13 of Set 14 | nome
# Processing Record 14 of Set 14 | baiyin
# Processing Record 15 of Set 14 | stornoway
# Processing Record 16 of Set 14 | vilyuysk
# Processing Record 17 of Set 14 | san jeronimo
# Processing Record 18 of Set 14 | damietta
# Processing Record 19 of Set 14 | findlay
# Processing Record 20 of Set 14 | impfondo
# Processing Record 21 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 22 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 14 | pietarsaari
# Processing Record 25 of Set 14 | dalvik
# Processing Record 26 of Set 14 | macomb
# Processing Record 27 of Set 14 | itaituba
# Processing Record 28 of Set 14 | mehamn
# Processing Record 29 of Set 14 | darhan
# Processing Record 30 of Set 14 | mogadishu
# Processing Record 31 of Set 14 | walvis bay
# Processing Record 32 of Set 14 | vanimo
# Processing Record 33 of Set 14 | ballina
# Processing Record 34 of Set 14 | bilara
# Processing Record 35 of Set 14 | bara
# Processing Record 36 of Set 14 | lagunas
# Processing Record 37 of Set 14 | alta floresta
# Processing Record 38 of Set 14 | morondava
# Processing Record 39 of Set 14 | bongandanga
# Processing Record 40 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 14 | antofagasta
# Processing Record 42 of Set 14 | chino valley
# Processing Record 43 of Set 14 | catacocha
# Processing Record 44 of Set 14 | byron bay
# Processing Record 45 of Set 14 | podor
# Processing Record 46 of Set 14 | helong
# Processing Record 47 of Set 14 | mount isa
# Processing Record 48 of Set 14 | papara
# Processing Record 49 of Set 14 | pyay
# Processing Record 50 of Set 14 | cordoba
# Processing Record 1 of Set 15 | port hedland
# Processing Record 2 of Set 15 | santa cruz das palmeiras
# Processing Record 3 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 15 | san ignacio
# Processing Record 5 of Set 15 | kysyl-syr
# Processing Record 6 of Set 15 | azare
# Processing Record 7 of Set 15 | dongsheng
# Processing Record 8 of Set 15 | mpanda
# Processing Record 9 of Set 15 | waddan
# Processing Record 10 of Set 15 | chimbote
# Processing Record 11 of Set 15 | maraa
# Processing Record 12 of Set 15 | timmins
# Processing Record 13 of Set 15 | papenburg
# Processing Record 14 of Set 15 | oskemen
# Processing Record 15 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 15 | riyadh
# Processing Record 17 of Set 15 | sangar
# Processing Record 18 of Set 15 | pahrump
# Processing Record 19 of Set 15 | yerbogachen
# Processing Record 20 of Set 15 | notre-dame-du-lac
# Processing Record 21 of Set 15 | gambela
# Processing Record 22 of Set 15 | copiapo
# Processing Record 23 of Set 15 | nakatsugawa
# Processing Record 24 of Set 15 | rock sound
# Processing Record 25 of Set 15 | caravelas
# Processing Record 26 of Set 15 | beirut
# Processing Record 27 of Set 15 | pandan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 0

# %%
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
